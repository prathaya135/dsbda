# %%
 import pandas as pd
 import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset_Facebook.csv', sep=";")  
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df1=df[['Page total likes','Category','Post Month','Post Weekday']].loc[0:50]

# %%
df1
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
df2=df[['Page total likes','Category','Post Month','Post Weekday']].loc[51:100] #same column names are used with differ rows range as for second subset
df2
# Out:
#      Page total likes  Category  Post Month  Post Weekday
# 51             138329         1          11             1
# 52             138329         1          11             7
# 53             138329         1          11             7
# 54             138329         1          11             6
# 55             138329         1          11             6
# 56             138329         1          11             5
# 57             138329         1          11             5
# 58             138329         1          11             4
# 59             138329         1          11             4
# 60             138185         1          11             3
# 61             138185         1          11             3
# 62             138185         1          11             2
# 63             138185         1          11             2
# 64             138185         1          11             1
# 65             138185         1          11             1
# ...

# %%
df3=df[['Page total likes','Category','Post Month','Post Weekday']].loc[101:200] #same column names are used with differ rows range as for third subset
df3
# Out:
#      Page total likes  Category  Post Month  Post Weekday
# 101            137020         2          10             4
# 102            137020         3          10             3
# 103            137020         1          10             3
# 104            137020         1          10             2
# 105            137020         1          10             2
# ..                ...       ...         ...           ...
# 196            133594         1           8             6
# 197            133594         2           8             5
# 198            133451         1           8             4
# 199            132817         3           8             4
# 200            132817         2           8             4
#
# [100 rows x 4 columns]

# %%
Merging=pd.concat([df1,df2,df3])   #num of subset can be differ
Merging
# Out:
#      Page total likes  Category  Post Month  Post Weekday
# 0              139441         2          12             4
# 1              139441         2          12             3
# 2              139441         3          12             3
# 3              139441         2          12             2
# 4              139441         2          12             2
# ..                ...       ...         ...           ...
# 196            133594         1           8             6
# 197            133594         2           8             5
# 198            133451         1           8             4
# 199            132817         3           8             4
# 200            132817         2           8             4
#
# [201 rows x 4 columns]

# %%
sorted=df.sort_values('Page total likes', ascending=False) #By default it is ascending order
sorted
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
NEW=df.transpose()  #transpose is stored in NEW variable
NEW
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
NEW.shape
# Out:
# (19, 500)

# %%
df.Type.unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
pd.melt(df, id_vars =['Type'], value_vars =['comment'])
# Out:
#        Type variable  value
# 0     Photo  comment      4
# 1    Status  comment      5
# 2     Photo  comment      0
# 3     Photo  comment     58
# 4     Photo  comment     19
# ..      ...      ...    ...
# 495   Photo  comment      5
# 496   Photo  comment      0
# 497   Photo  comment      4
# 498   Photo  comment      7
# 499   Photo  comment      0
#
# [500 rows x 3 columns]

# %%
pivot_value=pd.pivot_table(df,index= ['Type','Category'], values='share')   #values parameter can be changed to other features as comment,like or share
pivot_value
# Out:
#                      share
# Type   Category
# Link   1         12.700000
#        2         15.000000
#        3         15.000000
# Photo  1         17.961326
#        2         35.505495
#        3         33.193333
# Status 1         27.000000
#        2         32.105263
#        3         28.250000
# Video  1         52.142857

# %%
reshaping_arr=np.array([1,2,3,4,5,6])
reshaping_arr.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
sns.boxplot(data=df, x='Page total likes')
# Out:
# <AxesSubplot:xlabel='Page total likes'>

# %%
sns.histplot(data=df, x='Page total likes')
# Out:
# <AxesSubplot:xlabel='Page total likes', ylabel='Count'>

# %%
sns.lineplot(data=df, x='like',y='share')
# Out:
# <AxesSubplot:xlabel='like', ylabel='share'>

# %%
sns.lineplot(data=df, x='Type',y='Category',hue='Post Hour')
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Category'>
