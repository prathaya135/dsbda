# %%
import requests # type: ignore
import bs4 # type: ignore

# %%
request = requests.get('https://www.flipkart.com/poco-m6-pro-5g-forest-green-128-gb/p/itm151f47ed48eee?pid=MOBGRNZ3FZBVRYHQ&lid=LSTMOBGRNZ3FZBVRYHQLWWUJH&marketplace=FLIPKART&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=b_1_1&otracker=browse&fm=organic&iid=b4b7f16e-c3bb-42ac-9787-05e1db782e7f.MOBGRNZ3FZBVRYHQ.SEARCH&ppt=browse&ppn=browse&ssid=ggg9exx9ls0000001715107250093')
request   #503 responses
# Out:
# <Response [200]>

# %%
request.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
soup =bs4.BeautifulSoup(request.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
rewiews= soup.findAll('div',{'class':'ZmyHeo'});
for review in rewiews:
    print(review.get_text()+"\n\n")
# Out:
# Best value for money.Based on pricePerformance -5/5Back Camera-3/5Front camera-2.5/5Battery -4.5/5Charging-3/5Display-4.5/5Software-2/5( bloatware)Speed-4/5Design-4/5READ MORE
#
#
# To Good Design and Performance , but Charging timing Little slowREAD MORE
#
#
# Best mobile at this price range 👍🏻READ MORE
#
#
# Good one go for it camera is good..READ MORE
#
#
# Best phone in this price rangeREAD MORE
#
#
# Good mobile 5g this range and good workingREAD MORE
#
#
# Most Stylish Mobile from POCO.Performance is Great Camera is descent its ok,Mobile display Colour is average but still the build quality is Impressed me.😉🤗💥READ MORE
#
#
# AmazingREAD MORE
#
#
# Thank you Flipkart this item is very nice 💯READ MORE
#
#
# If you want a camera phone then don't buy it, it's only a budget 5g phone for daily uses. 🙂READ MORE

# %% [markdown]
# FETCH RATING

# %%
rating= soup.find_all('div',{'class':'XQDdHH Ga3i8K'});
for review in rating:
    print(review.get_text()+"\n\n")
# rating
# Out:
# 5
#
#
# 4
#
#
# 4
#
#
# 4
#
#
# 4
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 4

# %%
customer= soup.find_all('div',{'class':'row gHqwa8'});
# customer= soup.find_all('div',{'class':'_2NsDsF AwS1CA'});
for review in customer:
    print(review.get_text()+"\n\n")
# Out:
# AQEEL SHAIKCertified Buyer, Hyderabad8 months ago3560749PermalinkReport Abuse
#
#
# Rajkumar  ThakurCertified Buyer, Indore8 months ago28474PermalinkReport Abuse
#
#
# Siddhant  DhanwateCertified Buyer, Pune8 months ago614177PermalinkReport Abuse
#
#
# PRADEEP  D C Certified Buyer, Hangal8 months ago21358PermalinkReport Abuse
#
#
# Sunil SutharCertified Buyer, Jaipur8 months ago648209PermalinkReport Abuse
#
#
# Javed AlamCertified Buyer, New Delhi8 months ago13731PermalinkReport Abuse
#
#
# Tamilselvan GCertified Buyer, Salem8 months ago669190PermalinkReport Abuse
#
#
# Sachin ShindeCertified Buyer, Nanded8 months ago778226PermalinkReport Abuse
#
#
# Washim ShaikhCertified Buyer, Beldanga8 months ago895268PermalinkReport Abuse
#
#
# Ankit AgrahariCertified Buyer, Ambedkar Nagar District8 months ago8922PermalinkReport Abuse
